# %%
shape_path = '/mnt/d/Research/data/partnet-mobility-v0/dataset/3398'
import json
import numpy as np
import pyvista as pv

shape_mobility = json.load(open(shape_path + '/mobility_v2.json'))
result = json.load(open(shape_path + '/result.json'))

# 假设你的点存储在一个名为points的numpy数组中
points = np.random.rand(100, 3)  # 生成一些随机点

# 创建一个PointCloud对象
cloud = pv.PolyData(points)

# 创建一个plotter对象，并添加你的点云
plotter = pv.Plotter()
plotter.add_mesh(cloud, color="red", point_size=5.0)

# 添加坐标轴
plotter.add_axes()

# 显示图形
plotter.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 23
#      20 plotter.add_axes()
#      22 # 显示图形
# ---> 23 plotter.show()
#
# File ~/miniconda3/envs/gao/lib/python3.10/site-packages/pyvista/plotting/plotter.py:6734, in Plotter.show(self, title, window_size, interactive, auto_close, interactive_update, full_screen, screenshot, return_img, cpos, jupyter_backend, return_viewer, return_cpos, before_close_callback, **kwargs)
#    6731         jupyter_backend = self._theme.jupyter_backend
#    6733     if jupyter_backend.lower() != 'none':
# -> 6734         jupyter_disp = handle_plotter(self, backend=jupyter_backend, **jupyter_kwargs)
#    6736 self.render()
#    6738 # initial double render needed for certain passes when offscreen
#
# File ~/miniconda3/envs/gao/lib/python3.10/site-packages/pyvista/jupyter/notebook.py:31, in handle_plotter(plotter, backend, screenshot, **kwargs)
#      28     if backend in ['server', 'client', 'trame', 'html']:
#      29         from pyvista.trame.jupyter import show_trame
# ---> 31         return show_trame(plotter, mode=backend, **kwargs)
#      33 except ImportError as e:
#      34     warnings.warn(
#      35         f'Failed to use notebook backend: \n\n{e}\n\nFalling back to a static output.'
#      36     )
#
# File ~/miniconda3/envs/gao/lib/python3.10/site-packages/pyvista/trame/jupyter.py:385, in show_trame(plotter, mode, name, server_proxy_enabled, server_proxy_prefix, jupyter_extension_enabled, collapse_menu, add_menu, add_menu_items, default_server_rendering, handler, **kwargs)
#     382     raise TrameServerDownError(name)
#     384 # Initialize app
# --> 385 viewer = initialize(
#     386     server,
#     387     plotter,
#     388     mode=mode,
#     389     default_server_rendering=default_server_rendering,
#     390     collapse_menu=collapse_menu,
#     391     add_menu=add_menu,
#     392     add_menu_items=add_menu_items,
#     393 )
#     395 if jupyter_extension_enabled:  # pragma: no cover
#     396     from trame_client.ui.core import iframe_url_builder_jupyter_extension
#
# File ~/miniconda3/envs/gao/lib/python3.10/site-packages/pyvista/trame/jupyter.py:244, in initialize(server, plotter, mode, default_server_rendering, collapse_menu, **kwargs)
#     242 with viewer.make_layout(server, template_name=plotter._id_name) as layout:
#     243     viewer.layout = layout
# --> 244     viewer.ui(
#     245         mode=mode,
#     246         default_server_rendering=default_server_rendering,
#     247         collapse_menu=collapse_menu,
#     248         **kwargs,
#     249     )
#     251 return viewer
#
# File ~/miniconda3/envs/gao/lib/python3.10/site-packages/pyvista/trame/ui/vuetify3.py:315, in Viewer.ui(self, mode, default_server_rendering, collapse_menu, add_menu, add_menu_items, **kwargs)
#     313                     add_menu_items()
#     314 if mode == 'trame':
# --> 315     view = PyVistaRemoteLocalView(
#     316         self.plotter,
#     317         mode=(
#     318             # Must use single-quote string for JS here
#     319             f"{self.SERVER_RENDERING} ? 'remote' : 'local'",
#     320             'remote' if default_server_rendering else 'local',
#     321         ),
#     322         **kwargs,
#     323     )
#     324 elif mode == 'server':
#     325     view = PyVistaRemoteView(self.plotter, **kwargs)
#
# File ~/miniconda3/envs/gao/lib/python3.10/site-packages/pyvista/trame/views.py:244, in PyVistaRemoteLocalView.__init__(self, plotter, interactive_ratio, still_ratio, namespace, **kwargs)
#     242 if still_ratio is None:
#     243     still_ratio = plotter._theme.trame.still_ratio
# --> 244 VtkRemoteLocalView.__init__(
#     245     self,
#     246     self._plotter().render_window,
#     247     interactive_ratio=interactive_ratio,
#     248     still_ratio=still_ratio,
#     249     __properties=[('still_ratio', 'stillRatio')],
#     250     ref=f'view_{plotter._id_name}',
#     251     namespace=namespace,
#     252     **kwargs,
#     253 )
#     254 # Track namespace for our use since trame attributes are name mangled
#     255 self._namespace = namespace
#
# File ~/miniconda3/envs/gao/lib/python3.10/site-packages/trame_vtk/widgets/vtk/common.py:376, in VtkRemoteLocalView.__init__(self, view, enable_rendering, widgets, **kwargs)
#     373 self._helper = None
#     374 self._helper = activate_module_for(self._helper, self.server, view)
# --> 376 self._helper.has_capabilities("web", "rendering")
#     378 __ns = kwargs.get("namespace", "view")
#     380 if __ns == "view":
#
# AttributeError: 'NoneType' object has no attribute 'has_capabilities'
