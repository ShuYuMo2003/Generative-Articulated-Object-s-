# %%
import torch
from transformer.layers.quantizer import VectorQuantizer

# %%
vq = VectorQuantizer(n_e=4, e_dim=5, d_model=16, \
                     n_channel=5, temperature=1, beta=0.25, device='cpu')

# %%
z = torch.randn(5, 16) # batch = 5, dim = 16

# %%
vq(z)
# Out:
# logits_score tensor([[0.2808, 0.3438, 0.2219, 0.0853],
#         [1.7237, 1.7852, 1.7238, 2.3534],
#         [0.3491, 0.3626, 0.2969, 0.6101],
#         [1.2045, 1.3280, 1.1712, 1.3381],
#         [1.2040, 1.9998, 1.8768, 1.1833],
#         [0.9414, 1.0495, 0.8624, 1.2852],
#         [2.5063, 2.2080, 2.0900, 2.3565],
#         [3.8777, 4.3440, 4.0978, 3.7289],
#         [7.1368, 7.6473, 6.8868, 7.4369],
#         [4.1142, 3.4554, 3.4802, 4.7688],
#         [1.3926, 1.4498, 1.1095, 1.2085],
#         [2.3820, 2.1310, 2.4237, 3.0941],
#         [1.9145, 1.3953, 1.4337, 2.2899],
#         [0.6219, 0.9484, 0.9940, 0.9755],
#         [3.5290, 4.0802, 3.7428, 2.7225],
#         [6.3047, 7.2670, 6.6489, 6.3274],
#         [3.3358, 2.9782, 2.6944, 2.7420],
#         [0.5745, 0.7139, 0.9913, 0.8782],
#         [2.3621, 2.2674, 2.4989, 1.9979],
#         [1.1727, 1.3192, 1.2247, 0.9001],
#         [0.5702, 0.8618, 0.8343, 0.7415],
#         [1.5449, 1.2382, 1.1167, 1.7045],
# ...

# %%
del VectorQuantizer
